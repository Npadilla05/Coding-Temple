# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %%
df_snow = pd.read_csv(r'C:\Users\Noki\Downloads\archive (7)\annualsnow.csv', sep=',')
df_resort = pd.read_csv(r'C:\Users\Noki\Downloads\archive (7)\skiresorts.csv', sep=',')

# %%
display(df_snow)
display(df_resort)
# Out:
#       Location           Resort  Pass            Year Total Snowfall  \
# 0         utah             Alta  Ikon     2012 - 2013           366"
# 1         utah             Alta  Ikon     2013 - 2014           353"
# 2         utah             Alta  Ikon     2014 - 2015           278"
# 3         utah             Alta  Ikon     2015 - 2016           286"
# 4         utah             Alta  Ikon     2016 - 2017           304"
# ..         ...              ...   ...             ...            ...
# 865  wisconsin  Wilmot Mountain  Epic     2017 - 2018            37"
# 866  wisconsin  Wilmot Mountain  Epic     2018 - 2019            35"
# 867  wisconsin  Wilmot Mountain  Epic     2019 - 2020             6"
# 868  wisconsin  Wilmot Mountain  Epic     2020 - 2021            22"
# 869  wisconsin  Wilmot Mountain  Epic  2021 - To Date            10"
#
#      Snowfall Days Average Base Depth Average Summit Depth Max Base Depth  \
# 0               76                50"                  52"           113"
# 1               68                64"                  60"           124"
# 2               56                44"                  42"            90"
# 3               60                51"                  51"           116"
# 4               55                64"                  63"           145"
# ..             ...                ...                  ...            ...
# 865             15                 6"                  10"            28"
# 866              9                 9"                  15"            24"
# 867              1                 9"                  17"            29"
# 868             11                 9"                  10"            20"
# 869              4                19"                  18"            64"
#
#     Biggest Snowfall
# 0                17"
# 1                14"
# 2                19"
# 3                19"
# 4                19"
# ..               ...
# 865               8"
# 866              10"
# 867               6"
# 868               5"
# 869               4"
#
# [870 rows x 10 columns]
#       Location           Resort  Pass Limited or unlimited  Total Lifts  \
# 0         utah             Alta  Ikon              limited            6
# 1     colorado   Arapahoe Basin  Ikon              limited            9
# 2     colorado   Aspen Snowmass  Ikon              limited           40
# 3   california    Bear Mountain  Ikon            unlimited           12
# 4      montana          Big Sky  Ikon              limited           36
# ..         ...              ...   ...                  ...          ...
# 82    michigan     Mt. Brighton  Epic              limited           13
# 83    trentino             Pejo  Epic              limited            7
# 84    trentino          Pinzolo  Epic              limited           14
# 85    colorado        Telluride  Epic              limited           17
# 86   wisconsin  Wilmot Mountain  Epic            unlimited           11
#
#    Summit height Vertical Drop Base Elevation Runs in Total Longest Run  ...  \
# 0         11068'         2538'          8530'           119      1.3 mi  ...
# 1         13050'         2530'         10780'           147      1.5 mi  ...
# 2         12510'         4406'          8104'           336      5.3 mi  ...
# 3          8805'         1665'          7140'            15      1.5 mi  ...
# 4         11166'         4350'          7500'           317        6 mi  ...
# ..           ...           ...            ...           ...         ...  ...
# 82         1330'          230'          1100'            25      0.1 mi  ...
# 83         3000m         1600m          1160m         20 km        8 km  ...
# 84         2100m         1300m           800m       31.4 km      5.2 km  ...
# 85        13150'         4425'          8725'           147      4.6 mi  ...
# 86         1030'          230'           800'            21      0.5 mi  ...
#
#            Projected Closing Projected Days Open Days Open Last Year  \
# 0   April 25  20222022/04/25                 142                 156
# 1    June 05  20222022/06/05                 270                 234
# 2   April 17  20222022/04/17                 148                 150
# 3   April 16  20222022/04/16                 135                 122
# 4   April 24  20222022/04/24                 143                 144
# ..                       ...                 ...                 ...
# 82  March 13  20222022/03/13                  99                 111
# 83  April 18  20222022/04/18                N.A.                N.A.
# 84  April 18  20222022/04/18                N.A.                N.A.
# 85  April 17  20222022/04/17                 129                 136
# 86  March 13  20222022/03/13                 139                 125
#
#    Years Open Average Snowfall Beginners Runs Intermediate Runs Advanced Runs  \
# 0          84             547"            NaN               NaN           NaN
# 1          76             350"             7%               20%           49%
# 2          75             300"            NaN               NaN           NaN
# 3          79             100"            20%               33%           33%
# 4          49             400"            15%               25%           42%
# ..        ...              ...            ...               ...           ...
# 82         62              60"            24%               44%           24%
# 83       N.A.              0cm            NaN               25%           65%
# 84         53              0cm            NaN               12%           41%
# 85         50             280"            16%               30%           21%
# 86         84              70"            33%               33%           33%
#
#    Expert Runs Night Skiing
# 0          NaN          NaN
# 1          24%          NaN
# 2          NaN          NaN
# 3          13%          NaN
# 4          18%          NaN
# ..         ...          ...
# 82          8%       130 ac
# 83         10%       0.9 km
# 84         47%          NaN
# 85         34%          NaN
# 86         NaN       135 ac
#
# [87 rows x 23 columns]

# %%
# Lower case all column names
df_resort.columns = df_resort.columns.str.lower()
df_snow.columns = df_snow.columns.str.lower()

# %% [markdown]
# ### Drop symbols to convert data to integer or float

# %%
df_snow = df_snow.replace('"', '', regex=True) # regex specifies first argument is a regular expression. Replacing all instances with ''
df_resort = df_resort.replace('"', '', regex=True)

df_snow.columns = df_snow.columns.str.replace(' ','_') # Replace empty space with an underscore
df_resort.columns = df_resort.columns.str.replace(' ','_')

# df_snow['total_snowfall'].values # Getting error converting to (int) so i checked the values to find that 'cm' was included in some of the data
# df_snow['total_snowfall'] = df_snow['total_snowfall'].replace('cm', '', regex=True) # Dropped 'cm'
# df_snow['total_snowfall'].values # Double check values were correct
# df_snow['total_snowfall'] = df_snow['total_snowfall'].astype(int) # total_snowfall is now int

display(df_snow.head())
display(df_resort.head())
# Out:
#   location resort  pass         year total_snowfall  snowfall_days  \
# 0     utah   Alta  Ikon  2012 - 2013            366             76
# 1     utah   Alta  Ikon  2013 - 2014            353             68
# 2     utah   Alta  Ikon  2014 - 2015            278             56
# 3     utah   Alta  Ikon  2015 - 2016            286             60
# 4     utah   Alta  Ikon  2016 - 2017            304             55
#
#   average_base_depth average_summit_depth max_base_depth biggest_snowfall
# 0                 50                   52            113               17
# 1                 64                   60            124               14
# 2                 44                   42             90               19
# 3                 51                   51            116               19
# 4                 64                   63            145               19
#      location          resort  pass limited_or_unlimited  total_lifts  \
# 0        utah            Alta  Ikon              limited            6
# 1    colorado  Arapahoe Basin  Ikon              limited            9
# 2    colorado  Aspen Snowmass  Ikon              limited           40
# 3  california   Bear Mountain  Ikon            unlimited           12
# 4     montana         Big Sky  Ikon              limited           36
#
#   summit_height vertical_drop base_elevation runs_in_total longest_run  ...  \
# 0        11068'         2538'          8530'           119      1.3 mi  ...
# 1        13050'         2530'         10780'           147      1.5 mi  ...
# 2        12510'         4406'          8104'           336      5.3 mi  ...
# 3         8805'         1665'          7140'            15      1.5 mi  ...
# 4        11166'         4350'          7500'           317        6 mi  ...
#
#           projected_closing projected_days_open days_open_last_year  \
# 0  April 25  20222022/04/25                 142                 156
# 1   June 05  20222022/06/05                 270                 234
# 2  April 17  20222022/04/17                 148                 150
# 3  April 16  20222022/04/16                 135                 122
# 4  April 24  20222022/04/24                 143                 144
#
#   years_open average_snowfall beginners_runs intermediate_runs advanced_runs  \
# 0         84              547            NaN               NaN           NaN
# 1         76              350             7%               20%           49%
# 2         75              300            NaN               NaN           NaN
# 3         79              100            20%               33%           33%
# 4         49              400            15%               25%           42%
#
#   expert_runs night_skiing
# 0         NaN          NaN
# 1         24%          NaN
# 2         NaN          NaN
# 3         13%          NaN
# 4         18%          NaN
#
# [5 rows x 23 columns]

# %%
# df_snow['average_base_depth'] = df_snow['average_base_depth'].replace('cm', '', regex=True)
# df_snow['average_base_depth'] = df_snow['average_base_depth'].astype(int)

df_snow = df_snow.replace('cm', '',regex=True) # Realized the data included 'cm' so instead of doing indivd columns i replaced the entire data at once

df_snow['average_summit_depth'] = df_snow['average_summit_depth'].astype(int)
df_snow['total_snowfall'] = df_snow['total_snowfall'].astype(int) # total_snowfall is now int
df_snow['average_base_depth'] = df_snow['average_base_depth'].astype(int)

# %%
df_snow['average_summit_depth'] = df_snow['average_summit_depth'].astype(int)
df_snow['max_base_depth'] = df_snow['max_base_depth'].astype(int)
df_snow['biggest_snowfall'] = df_snow['biggest_snowfall'].astype(int)

# %%
# Rename columns to indicate that my data is in cm
df_snow = df_snow.rename(columns={'total_snowfall': 'total_snowfall(cm)', 'average_base_depth': 'average_base_depth(cm)', 'average_summit_depth': 'average_summit_depth(cm)',
                                  'max_base_depth': 'max_base_depth(cm)', 'biggest_snowfall': 'biggest_snowfall(cm)'
                                   })

# %%
df_snow['location'] = df_snow['location'].str.title() # Titlecase the location column values

# %%
display(df_snow)
df_snow.dtypes
# Out:
#       location           resort  pass            year  total_snowfall(cm)  \
# 0         Utah             Alta  Ikon     2012 - 2013                 366
# 1         Utah             Alta  Ikon     2013 - 2014                 353
# 2         Utah             Alta  Ikon     2014 - 2015                 278
# 3         Utah             Alta  Ikon     2015 - 2016                 286
# 4         Utah             Alta  Ikon     2016 - 2017                 304
# ..         ...              ...   ...             ...                 ...
# 865  Wisconsin  Wilmot Mountain  Epic     2017 - 2018                  37
# 866  Wisconsin  Wilmot Mountain  Epic     2018 - 2019                  35
# 867  Wisconsin  Wilmot Mountain  Epic     2019 - 2020                   6
# 868  Wisconsin  Wilmot Mountain  Epic     2020 - 2021                  22
# 869  Wisconsin  Wilmot Mountain  Epic  2021 - To Date                  10
#
#      snowfall_days  average_base_depth(cm)  average_summit_depth(cm)  \
# 0               76                      50                        52
# 1               68                      64                        60
# 2               56                      44                        42
# 3               60                      51                        51
# 4               55                      64                        63
# ..             ...                     ...                       ...
# 865             15                       6                        10
# 866              9                       9                        15
# 867              1                       9                        17
# 868             11                       9                        10
# 869              4                      19                        18
#
#      max_base_depth(cm)  biggest_snowfall(cm)
# 0                   113                    17
# 1                   124                    14
# 2                    90                    19
# 3                   116                    19
# 4                   145                    19
# ..                  ...                   ...
# 865                  28                     8
# 866                  24                    10
# 867                  29                     6
# 868                  20                     5
# 869                  64                     4
#
# [870 rows x 10 columns]
# location                    object
# resort                      object
# pass                        object
# year                        object
# total_snowfall(cm)           int32
# snowfall_days                int64
# average_base_depth(cm)       int32
# average_summit_depth(cm)     int32
# max_base_depth(cm)           int32
# biggest_snowfall(cm)         int32
# dtype: object

# %% [markdown]
# - df_snow is now cleaned. Next up is df_resorts
# - once resorts is cleaned we can merge both datasets

# %%
display(df_resort.head())
display(df_resort.dtypes)
# Out:
#      location          resort  pass limited_or_unlimited  total_lifts  \
# 0        utah            Alta  Ikon              limited            6
# 1    colorado  Arapahoe Basin  Ikon              limited            9
# 2    colorado  Aspen Snowmass  Ikon              limited           40
# 3  california   Bear Mountain  Ikon            unlimited           12
# 4     montana         Big Sky  Ikon              limited           36
#
#   summit_height vertical_drop base_elevation runs_in_total longest_run  ...  \
# 0        11068'         2538'          8530'           119      1.3 mi  ...
# 1        13050'         2530'         10780'           147      1.5 mi  ...
# 2        12510'         4406'          8104'           336      5.3 mi  ...
# 3         8805'         1665'          7140'            15      1.5 mi  ...
# 4        11166'         4350'          7500'           317        6 mi  ...
#
#           projected_closing projected_days_open days_open_last_year  \
# 0  April 25  20222022/04/25                 142                 156
# 1   June 05  20222022/06/05                 270                 234
# 2  April 17  20222022/04/17                 148                 150
# 3  April 16  20222022/04/16                 135                 122
# 4  April 24  20222022/04/24                 143                 144
#
#   years_open average_snowfall beginners_runs intermediate_runs advanced_runs  \
# 0         84              547            NaN               NaN           NaN
# 1         76              350             7%               20%           49%
# 2         75              300            NaN               NaN           NaN
# 3         79              100            20%               33%           33%
# 4         49              400            15%               25%           42%
#
#   expert_runs night_skiing
# 0         NaN          NaN
# 1         24%          NaN
# 2         NaN          NaN
# 3         13%          NaN
# 4         18%          NaN
#
# [5 rows x 23 columns]
# location                object
# resort                  object
# pass                    object
# limited_or_unlimited    object
# total_lifts              int64
# summit_height           object
# vertical_drop           object
# base_elevation          object
# runs_in_total           object
# longest_run             object
# skiable_terrain         object
# snow_making             object
# projected_opening       object
# projected_closing       object
# projected_days_open     object
# days_open_last_year     object
# years_open              object
# average_snowfall        object
# beginners_runs          object
# intermediate_runs       object
# advanced_runs           object
# expert_runs             object
# night_skiing            object
# dtype: object

# %% [markdown]
# # df_resort to-do list
# - longest run is in miles and km. convert
# - drop column limited_or_unlimited
# - drop '
# - drop %
# - projected_closing convert to datetime?
# - runs_in_total needs to drop km and convert to int
# - titlecase location column
# - night_skiing table has 'ac' or acres. needs converting

# %% [markdown]
# ### Convert KM to MI

# %%
# miles = km * 0.621371
# Converting km to mi
new = []
for value in df_resort['longest_run']:
    if type(value) == float:
        value = '0.0 mi'
        new.append(value)
    elif type(value) == str:
        l = value.split()
        if l[1] == 'km':
             l[0] = str(round(float(l[0])* 0.621371,1))
             l[1] = 'mi'
             new.append(' '.join(l))
        else:
            new.append(value)

print(new)
df_resort['longest_run'] = new
# Out:
# ['1.3 mi', '1.5 mi', '5.3 mi', '1.5 mi', '6 mi', '1 mi', '1 mi', '1.2 mi', '1.7 mi', '2.5 mi', '2.5 mi', '2.8 mi', '3 mi', '4.5 mi', '2 mi', '6 mi', '5 mi', '2.5 mi', '3 mi', '4 mi', '0.7 mi', '3.2 mi', '9.5 mi', '1.2 mi', '3.5 mi', '2.5 mi', '3 mi', '3 mi', '3 mi', '3 mi', '3.5 mi', '3 mi', '3 mi', '5 mi', '5 mi', '3.7 mi', '4.9 mi', '0.8 mi', '1.5 mi', '1.2 mi', '2 mi', '2.8 mi', '3.5 mi', '0.7 mi', '5.6 mi', '3.1 mi', '0.0 mi', '5.5 mi', '3.5 mi', '6.2 mi', '4 mi', '2.5 mi', '0.0 mi', '0.0 mi', '3.1 mi', '0.7 mi', '2.8 mi', '1.9 mi', '0.0 mi', '1.4 mi', '3.4 mi', '0.0 mi', '3.5 mi', '6.8 mi', '1.9 mi', '3.5 mi', '1 mi', '2 mi', '3.7 mi', '3 mi', '0.0 mi', '4 mi', '2.2 mi', '0.0 mi', '0.0 mi', '6.8 mi', '0.5 mi', '2.5 mi', '3.1 mi', '2.6 mi', '2.4 mi', '0.8 mi', '0.1 mi', '5.0 mi', '3.2 mi', '4.6 mi', '0.5 mi']

# %% [markdown]
# ### Replace and drop

# %%
df_resort = df_resort.replace('N.A.', 0)

# %%
df_resort = df_resort.drop(['limited_or_unlimited'], axis=1)
df_resort = df_resort.drop(['projected_closing'],axis=1)
df_resort = df_resort.drop(['projected_opening'],axis=1)
df_resort = df_resort.drop(['snow_making'],axis=1)

# %% [markdown]
# ### Convert KM to AC

# %%
new_list = []
for value in df_resort['skiable_terrain']:
    l = value.split()
    if l[1] == 'km':
        l[0] =round(float(l[0]) * 247.105, 1)
        
        new_list.append(l[0])
    else:
        new_list.append(l[0])
print(new_list)

df_resort['skiable_terrain'] = new_list
# Out:
# ['2614', '1428', '5517', '198', '5800', '365', '415', '1050', '2527', '2600', '600', '2026', '680', '2500', '1500', '1526', '4200', '370', '3500', '4323', '190', '6000', '3121', '240', '3000', '2500', '1200', '2965', '670', '581', '1240', '2054', '878', '3358', '1294', '754', '3081', '1994', '257', '435', '285', '1832', '2908', 37065.8, 37065.8, '2504', 15567.6, '4800', '3148', '2800', '1800', '2300', 37065.8, 39536.8, 14332.1, 37065.8, '547', '1021', 101807.3, '3170', '667', 37065.8, '7300', 24710.5, 39536.8, '3000', '1125', '333', '485', '2054', 101807.3, '5289', 37065.8, 101807.3, 101807.3, '8171', '250', 25525.9, 9884.2, '1547', 4695.0, '232', '130', 4942.1, 7759.1, '2000', '135']

# %%
df_resort= df_resort.drop_duplicates(subset=['skiable_terrain'])
df_resort
# Out:
#       location           resort  pass  total_lifts summit_height  \
# 0         utah             Alta  Ikon            6        11068'
# 1     colorado   Arapahoe Basin  Ikon            9        13050'
# 2     colorado   Aspen Snowmass  Ikon           40        12510'
# 3   california    Bear Mountain  Ikon           12         8805'
# 4      montana          Big Sky  Ikon           36        11166'
# ..         ...              ...   ...          ...           ...
# 82    michigan     Mt. Brighton  Epic           13         1330'
# 83    trentino             Pejo  Epic            7         3000m
# 84    trentino          Pinzolo  Epic           14         2100m
# 85    colorado        Telluride  Epic           17        13150'
# 86   wisconsin  Wilmot Mountain  Epic           11         1030'
#
#    vertical_drop base_elevation runs_in_total longest_run skiable_terrain  \
# 0          2538'          8530'           119      1.3 mi            2614
# 1          2530'         10780'           147      1.5 mi            1428
# 2          4406'          8104'           336      5.3 mi            5517
# 3          1665'          7140'            15      1.5 mi             198
# 4          4350'          7500'           317        6 mi            5800
# ..           ...            ...           ...         ...             ...
# 82          230'          1100'            25      0.1 mi             130
# 83         1600m          1160m         20 km      5.0 mi          4942.1
# 84         1300m           800m       31.4 km      3.2 mi          7759.1
# 85         4425'          8725'           147      4.6 mi            2000
# 86          230'           800'            21      0.5 mi             135
#
#    projected_days_open days_open_last_year years_open average_snowfall  \
# 0                  142                 156         84              547
# 1                  270                 234         76              350
# 2                  148                 150         75              300
# 3                  135                 122         79              100
# 4                  143                 144         49              400
# ..                 ...                 ...        ...              ...
# 82                  99                 111         62               60
# 83                   0                   0          0              0cm
# 84                   0                   0         53              0cm
# 85                 129                 136         50              280
# 86                 139                 125         84               70
#
#    beginners_runs intermediate_runs advanced_runs expert_runs night_skiing
# 0             NaN               NaN           NaN         NaN          NaN
# 1              7%               20%           49%         24%          NaN
# 2             NaN               NaN           NaN         NaN          NaN
# 3             20%               33%           33%         13%          NaN
# 4             15%               25%           42%         18%          NaN
# ..            ...               ...           ...         ...          ...
# 82            24%               44%           24%          8%       130 ac
# 83            NaN               25%           65%         10%       0.9 km
# 84            NaN               12%           41%         47%          NaN
# 85            16%               30%           21%         34%          NaN
# 86            33%               33%           33%         NaN       135 ac
#
# [75 rows x 19 columns]

# %% [markdown]
# ### Rename columns in df_resort

# %%
df_resort = df_resort.rename(columns={'summit_height': 'summit_height(ft)', 'vertical_drop': 'vertical_drop(ft)', 
                                      'base_elevation': 'base_elevation(ft)', 'longest_run': 'longest_run(mi)',
                                      'skiable_terrain': 'skiable_terrain(ac)', 'average_snowfall': 'average_snowfall(cm)',
                                      'beginners_runs': 'beginner_runs(%)', 'intermediate_runs': 'intermediate_runs(%)',
                                      'advanced_runs': 'advanced_runs(%)', 'expert_runs': 'expert_runs(%)'})

# %%
df_resort
# Out:
#       location           resort  pass  total_lifts summit_height(ft)  \
# 0         utah             Alta  Ikon            6            11068'
# 1     colorado   Arapahoe Basin  Ikon            9            13050'
# 2     colorado   Aspen Snowmass  Ikon           40            12510'
# 3   california    Bear Mountain  Ikon           12             8805'
# 4      montana          Big Sky  Ikon           36            11166'
# ..         ...              ...   ...          ...               ...
# 82    michigan     Mt. Brighton  Epic           13             1330'
# 83    trentino             Pejo  Epic            7             3000m
# 84    trentino          Pinzolo  Epic           14             2100m
# 85    colorado        Telluride  Epic           17            13150'
# 86   wisconsin  Wilmot Mountain  Epic           11             1030'
#
#    vertical_drop(ft) base_elevation(ft) runs_in_total longest_run(mi)  \
# 0              2538'              8530'           119          1.3 mi
# 1              2530'             10780'           147          1.5 mi
# 2              4406'              8104'           336          5.3 mi
# 3              1665'              7140'            15          1.5 mi
# 4              4350'              7500'           317            6 mi
# ..               ...                ...           ...             ...
# 82              230'              1100'            25          0.1 mi
# 83             1600m              1160m         20 km          5.0 mi
# 84             1300m               800m       31.4 km          3.2 mi
# 85             4425'              8725'           147          4.6 mi
# 86              230'               800'            21          0.5 mi
#
#    skiable_terrain(ac) projected_days_open days_open_last_year years_open  \
# 0                 2614                 142                 156         84
# 1                 1428                 270                 234         76
# 2                 5517                 148                 150         75
# 3                  198                 135                 122         79
# 4                 5800                 143                 144         49
# ..                 ...                 ...                 ...        ...
# 82                 130                  99                 111         62
# 83              4942.1                   0                   0          0
# 84              7759.1                   0                   0         53
# 85                2000                 129                 136         50
# 86                 135                 139                 125         84
#
#    average_snowfall(cm) beginner_runs(%) intermediate_runs(%)  \
# 0                   547              NaN                  NaN
# 1                   350               7%                  20%
# 2                   300              NaN                  NaN
# 3                   100              20%                  33%
# 4                   400              15%                  25%
# ..                  ...              ...                  ...
# 82                   60              24%                  44%
# 83                  0cm              NaN                  25%
# 84                  0cm              NaN                  12%
# 85                  280              16%                  30%
# 86                   70              33%                  33%
#
#    advanced_runs(%) expert_runs(%) night_skiing
# 0               NaN            NaN          NaN
# 1               49%            24%          NaN
# 2               NaN            NaN          NaN
# 3               33%            13%          NaN
# 4               42%            18%          NaN
# ..              ...            ...          ...
# 82              24%             8%       130 ac
# 83              65%            10%       0.9 km
# 84              41%            47%          NaN
# 85              21%            34%          NaN
# 86              33%            NaN       135 ac
#
# [75 rows x 19 columns]

# %%
to_clean = [df_resort['longest_run(mi)'], df_resort['runs_in_total'], df_resort['summit_height(ft)'], df_resort['vertical_drop(ft)'], df_resort['base_elevation(ft)'], df_resort['skiable_terrain(ac)'], df_resort['night_skiing']]
for col in to_clean:
    df_resort['longest_run(mi)'] = df_resort['longest_run(mi)'].str.replace('mi', '')
    df_resort['runs_in_total'] = df_resort['runs_in_total'].str.replace('km', '')
    df_resort['runs_in_total'] = df_resort['runs_in_total'].str.replace('mi', '')
    df_resort['summit_height(ft)'] =  df_resort['summit_height(ft)'].str.replace('m', '')
    df_resort['vertical_drop(ft)'] = df_resort['vertical_drop(ft)'].str.replace('m', '')
    df_resort['base_elevation(ft)'] = df_resort['base_elevation(ft)'].str.replace('m', '')
    df_resort['skiable_terrain(ac)'] = df_resort['skiable_terrain(ac)'].str.replace('ac', '')
    df_resort['skiable_terrain(ac)'] = df_resort['skiable_terrain(ac)'].str.replace('km', '')
    df_resort['night_skiing'] = df_resort['night_skiing'].str.replace('km', '')
    df_resort['night_skiing'] = df_resort['night_skiing'].str.replace('ac', '')

# %%
df_resort
# Out:
#       location           resort  pass  total_lifts summit_height(ft)  \
# 0         utah             Alta  Ikon            6            11068'
# 1     colorado   Arapahoe Basin  Ikon            9            13050'
# 2     colorado   Aspen Snowmass  Ikon           40            12510'
# 3   california    Bear Mountain  Ikon           12             8805'
# 4      montana          Big Sky  Ikon           36            11166'
# ..         ...              ...   ...          ...               ...
# 82    michigan     Mt. Brighton  Epic           13             1330'
# 83    trentino             Pejo  Epic            7              3000
# 84    trentino          Pinzolo  Epic           14              2100
# 85    colorado        Telluride  Epic           17            13150'
# 86   wisconsin  Wilmot Mountain  Epic           11             1030'
#
#    vertical_drop(ft) base_elevation(ft) runs_in_total longest_run(mi)  \
# 0              2538'              8530'           119            1.3
# 1              2530'             10780'           147            1.5
# 2              4406'              8104'           336            5.3
# 3              1665'              7140'            15            1.5
# 4              4350'              7500'           317              6
# ..               ...                ...           ...             ...
# 82              230'              1100'            25            0.1
# 83              1600               1160           20             5.0
# 84              1300                800         31.4             3.2
# 85             4425'              8725'           147            4.6
# 86              230'               800'            21            0.5
#
#    skiable_terrain(ac) projected_days_open days_open_last_year years_open  \
# 0                 2614                 142                 156         84
# 1                 1428                 270                 234         76
# 2                 5517                 148                 150         75
# 3                  198                 135                 122         79
# 4                 5800                 143                 144         49
# ..                 ...                 ...                 ...        ...
# 82                 130                  99                 111         62
# 83                 NaN                   0                   0          0
# 84                 NaN                   0                   0         53
# 85                2000                 129                 136         50
# 86                 135                 139                 125         84
#
#    average_snowfall(cm) beginner_runs(%) intermediate_runs(%)  \
# 0                   547              NaN                  NaN
# 1                   350               7%                  20%
# 2                   300              NaN                  NaN
# 3                   100              20%                  33%
# 4                   400              15%                  25%
# ..                  ...              ...                  ...
# 82                   60              24%                  44%
# 83                  0cm              NaN                  25%
# 84                  0cm              NaN                  12%
# 85                  280              16%                  30%
# 86                   70              33%                  33%
#
#    advanced_runs(%) expert_runs(%) night_skiing
# 0               NaN            NaN          NaN
# 1               49%            24%          NaN
# 2               NaN            NaN          NaN
# 3               33%            13%          NaN
# 4               42%            18%          NaN
# ..              ...            ...          ...
# 82              24%             8%         130
# 83              65%            10%         0.9
# 84              41%            47%          NaN
# 85              21%            34%          NaN
# 86              33%            NaN         135
#
# [75 rows x 19 columns]

# %%
# Removing labels from values in column
df_resort = df_resort.replace("'", "", regex=True)
df_resort = df_resort.replace("cm","", regex=True)
df_resort = df_resort.replace("%","", regex=True)

# %%
df_resort['location'] = df_resort['location'].str.title() # Title case location values to capitalize location names
df_resort
# Out:
#       location           resort  pass  total_lifts summit_height(ft)  \
# 0         Utah             Alta  Ikon            6             11068
# 1     Colorado   Arapahoe Basin  Ikon            9             13050
# 2     Colorado   Aspen Snowmass  Ikon           40             12510
# 3   California    Bear Mountain  Ikon           12              8805
# 4      Montana          Big Sky  Ikon           36             11166
# ..         ...              ...   ...          ...               ...
# 82    Michigan     Mt. Brighton  Epic           13              1330
# 83    Trentino             Pejo  Epic            7              3000
# 84    Trentino          Pinzolo  Epic           14              2100
# 85    Colorado        Telluride  Epic           17             13150
# 86   Wisconsin  Wilmot Mountain  Epic           11              1030
#
#    vertical_drop(ft) base_elevation(ft) runs_in_total longest_run(mi)  \
# 0               2538               8530           119            1.3
# 1               2530              10780           147            1.5
# 2               4406               8104           336            5.3
# 3               1665               7140            15            1.5
# 4               4350               7500           317              6
# ..               ...                ...           ...             ...
# 82               230               1100            25            0.1
# 83              1600               1160           20             5.0
# 84              1300                800         31.4             3.2
# 85              4425               8725           147            4.6
# 86               230                800            21            0.5
#
#    skiable_terrain(ac) projected_days_open days_open_last_year years_open  \
# 0                 2614                 142                 156         84
# 1                 1428                 270                 234         76
# 2                 5517                 148                 150         75
# 3                  198                 135                 122         79
# 4                 5800                 143                 144         49
# ..                 ...                 ...                 ...        ...
# 82                 130                  99                 111         62
# 83                 NaN                   0                   0          0
# 84                 NaN                   0                   0         53
# 85                2000                 129                 136         50
# 86                 135                 139                 125         84
#
#    average_snowfall(cm) beginner_runs(%) intermediate_runs(%)  \
# 0                   547              NaN                  NaN
# 1                   350                7                   20
# 2                   300              NaN                  NaN
# 3                   100               20                   33
# 4                   400               15                   25
# ..                  ...              ...                  ...
# 82                   60               24                   44
# 83                    0              NaN                   25
# 84                    0              NaN                   12
# 85                  280               16                   30
# 86                   70               33                   33
#
#    advanced_runs(%) expert_runs(%) night_skiing
# 0               NaN            NaN          NaN
# 1                49             24          NaN
# 2               NaN            NaN          NaN
# 3                33             13          NaN
# 4                42             18          NaN
# ..              ...            ...          ...
# 82               24              8         130
# 83               65             10         0.9
# 84               41             47          NaN
# 85               21             34          NaN
# 86               33            NaN         135
#
# [75 rows x 19 columns]

# %%
# night = []
# for value in df_resort['night_skiing']:
#     if value == np.nan:
#         print('False')
#     else:
#         print('True')

df_resort['night_skiing'] = df_resort['night_skiing'].replace({1: True, 0: False})
df_resort['night_skiing'] = df_resort['night_skiing'].fillna(False)
# Change  values in night skiing to be boolean

# %%
df_resort['night_skiing'].values
# Out:
# array([False, False, False, False, False, '260 ', '200 ', '200 ', False,
#        False, '66 ', False, False, False, False, False, False, False,
#        False, False, '20 ', False, False, '150 ', False, False, '30 ',
#        False, False, False, False, '140 ', False, False, False, False,
#        '541 ', '86 ', '150 ', '45 ', False, False, False, False, False,
#        False, '288 ', False, '120 ', False, False, '0.6 ', '136 ', False,
#        False, False, False, False, '3 ', '450 ', '156 ', False, False,
#        False, '250 ', False, '3 ', False, '5 ', False, '130 ', '0.9 ',
#        False, False, '135 '], dtype=object)

# %%
df_resort['night_skiing'] = pd.to_numeric(df_resort['night_skiing'], errors='coerce')
df_resort['night_skiing'] = df_resort['night_skiing'].astype(bool)

# %%
df_resort.dtypes
df_resort['night_skiing'].values # Instead of displaying values, I wanted the data to display True or False
# Out:
# array([False, False, False, False, False,  True,  True,  True, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False,  True, False, False,  True, False, False,  True,
#        False, False, False, False,  True, False, False, False, False,
#         True,  True,  True,  True, False, False, False, False, False,
#        False,  True, False,  True, False, False,  True,  True, False,
#        False, False, False, False,  True,  True,  True, False, False,
#        False,  True, False,  True, False,  True, False,  True,  True,
#        False, False,  True])

# %%
df_resort
# Out:
#       location           resort  pass  total_lifts summit_height(ft)  \
# 0         Utah             Alta  Ikon            6             11068
# 1     Colorado   Arapahoe Basin  Ikon            9             13050
# 2     Colorado   Aspen Snowmass  Ikon           40             12510
# 3   California    Bear Mountain  Ikon           12              8805
# 4      Montana          Big Sky  Ikon           36             11166
# ..         ...              ...   ...          ...               ...
# 82    Michigan     Mt. Brighton  Epic           13              1330
# 83    Trentino             Pejo  Epic            7              3000
# 84    Trentino          Pinzolo  Epic           14              2100
# 85    Colorado        Telluride  Epic           17             13150
# 86   Wisconsin  Wilmot Mountain  Epic           11              1030
#
#    vertical_drop(ft) base_elevation(ft) runs_in_total longest_run(mi)  \
# 0               2538               8530           119            1.3
# 1               2530              10780           147            1.5
# 2               4406               8104           336            5.3
# 3               1665               7140            15            1.5
# 4               4350               7500           317              6
# ..               ...                ...           ...             ...
# 82               230               1100            25            0.1
# 83              1600               1160           20             5.0
# 84              1300                800         31.4             3.2
# 85              4425               8725           147            4.6
# 86               230                800            21            0.5
#
#    skiable_terrain(ac) projected_days_open days_open_last_year years_open  \
# 0                 2614                 142                 156         84
# 1                 1428                 270                 234         76
# 2                 5517                 148                 150         75
# 3                  198                 135                 122         79
# 4                 5800                 143                 144         49
# ..                 ...                 ...                 ...        ...
# 82                 130                  99                 111         62
# 83                 NaN                   0                   0          0
# 84                 NaN                   0                   0         53
# 85                2000                 129                 136         50
# 86                 135                 139                 125         84
#
#    average_snowfall(cm) beginner_runs(%) intermediate_runs(%)  \
# 0                   547              NaN                  NaN
# 1                   350                7                   20
# 2                   300              NaN                  NaN
# 3                   100               20                   33
# 4                   400               15                   25
# ..                  ...              ...                  ...
# 82                   60               24                   44
# 83                    0              NaN                   25
# 84                    0              NaN                   12
# 85                  280               16                   30
# 86                   70               33                   33
#
#    advanced_runs(%) expert_runs(%)  night_skiing
# 0               NaN            NaN         False
# 1                49             24         False
# 2               NaN            NaN         False
# 3                33             13         False
# 4                42             18         False
# ..              ...            ...           ...
# 82               24              8          True
# 83               65             10          True
# 84               41             47         False
# 85               21             34         False
# 86               33            NaN          True
#
# [75 rows x 19 columns]

# %%
df_resort['skiable_terrain(ac)'].drop_duplicates(inplace=True)
df_resort['skiable_terrain(ac)']
# Out:
# 0     2614
# 1     1428
# 2     5517
# 3      198
# 4     5800
#       ...
# 82     130
# 83     NaN
# 84     NaN
# 85    2000
# 86     135
# Name: skiable_terrain(ac), Length: 75, dtype: object

# %%
# df_resort['skiable_terrain(ac)'] = df_resort['skiable_terrain(ac)'].str.strip().str.replace(' ', '')

df_resort = df_resort.drop_duplicates(subset=['skiable_terrain(ac)'], keep='first')

# %% [markdown]
# ### Convert datatypes

# %%
df_resort
# Out:
#          location           resort  pass  total_lifts summit_height(ft)  \
# 0            Utah             Alta  Ikon            6             11068
# 1        Colorado   Arapahoe Basin  Ikon            9             13050
# 2        Colorado   Aspen Snowmass  Ikon           40             12510
# 3      California    Bear Mountain  Ikon           12              8805
# 4         Montana          Big Sky  Ikon           36             11166
# ..            ...              ...   ...          ...               ...
# 79       Colorado    Crested Butte  Epic           14             12162
# 81  New-Hampshire    Mount Sunapee  Epic           10              2743
# 82       Michigan     Mt. Brighton  Epic           13              1330
# 85       Colorado        Telluride  Epic           17             13150
# 86      Wisconsin  Wilmot Mountain  Epic           11              1030
#
#    vertical_drop(ft) base_elevation(ft) runs_in_total longest_run(mi)  \
# 0               2538               8530           119            1.3
# 1               2530              10780           147            1.5
# 2               4406               8104           336            5.3
# 3               1665               7140            15            1.5
# 4               4350               7500           317              6
# ..               ...                ...           ...             ...
# 79              3062               9375           121            2.6
# 81              1510               1233            66            0.8
# 82               230               1100            25            0.1
# 85              4425               8725           147            4.6
# 86               230                800            21            0.5
#
#    skiable_terrain(ac) projected_days_open days_open_last_year years_open  \
# 0                 2614                 142                 156         84
# 1                 1428                 270                 234         76
# 2                 5517                 148                 150         75
# 3                  198                 135                 122         79
# 4                 5800                 143                 144         49
# ..                 ...                 ...                 ...        ...
# 79                1547                 137                 145         61
# 81                 232                 130                 130         74
# 82                 130                  99                 111         62
# 85                2000                 129                 136         50
# 86                 135                 139                 125         84
#
#    average_snowfall(cm) beginner_runs(%) intermediate_runs(%)  \
# 0                   547              NaN                  NaN
# 1                   350                7                   20
# 2                   300              NaN                  NaN
# 3                   100               20                   33
# 4                   400               15                   25
# ..                  ...              ...                  ...
# 79                  234               14                   25
# 81                  100               30                   46
# 82                   60               24                   44
# 85                  280               16                   30
# 86                   70               33                   33
#
#    advanced_runs(%) expert_runs(%)  night_skiing
# 0               NaN            NaN         False
# 1                49             24         False
# 2               NaN            NaN         False
# 3                33             13         False
# 4                42             18         False
# ..              ...            ...           ...
# 79               25             36         False
# 81               11             13         False
# 82               24              8          True
# 85               21             34         False
# 86               33            NaN          True
#
# [65 rows x 19 columns]

# %%
df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('18.2', '18',regex=True)
df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('41.8', '41',regex=True)
df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('39.2', '39',regex=True)
df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('103.3', '103',regex=True)
df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('31.4', '31',regex=True)

df_resort['runs_in_total']
# Out:
# C:\Users\Noki\AppData\Local\Temp\ipykernel_30948\2248216896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('18.2', '18',regex=True)
# C:\Users\Noki\AppData\Local\Temp\ipykernel_30948\2248216896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('41.8', '41',regex=True)
# C:\Users\Noki\AppData\Local\Temp\ipykernel_30948\2248216896.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('39.2', '39',regex=True)
# C:\Users\Noki\AppData\Local\Temp\ipykernel_30948\2248216896.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('103.3', '103',regex=True)
# C:\Users\Noki\AppData\Local\Temp\ipykernel_30948\2248216896.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resort['runs_in_total'] = df_resort['runs_in_total'].replace('31.4', '31',regex=True)
# 0     119
# 1     147
# 2     336
# 3      15
# 4     317
#      ...
# 79    121
# 81     66
# 82     25
# 85    147
# 86     21
# Name: runs_in_total, Length: 65, dtype: object

# %%
df_resort['runs_in_total'].values
# Out:
# array(['119', '147', '336', '15', '317', '55', '60', '66', '150', '86',
#        '61', '103', '61', '131', '43', '155', '164', '61', '150', '119',
#        '60', '245', '59', '27', '41 ', '82', '169', '99', '111', '162',
#        '120', '135', '145', '110', '102', '161', '65', '61', '55', '18 ',
#        '150', '187', '150 ', '142', '97', '128', '129', '80', '90', '71',
#        '75', '100', '39 ', '341', '53', '43', '116', '267', '234', '48',
#        '121', '66', '25', '147', '21'], dtype=object)

# %%
df_resort = df_resort.replace(np.nan, 0) # Converted NaN to 0 in order to get the runs columns to an integer

# %%
df_resort['summit_height(ft)'] = df_resort['summit_height(ft)'].astype(int)
df_resort['vertical_drop(ft)'] = df_resort['vertical_drop(ft)'].astype(int)
df_resort['base_elevation(ft)'] = df_resort['base_elevation(ft)'].astype(int)
df_resort['runs_in_total'] = df_resort['runs_in_total'].astype(int)
df_resort['longest_run(mi)'] = df_resort['longest_run(mi)'].astype(float)
df_resort['projected_days_open'] = df_resort['projected_days_open'].astype(int)
df_resort['years_open'] = df_resort['years_open'].astype(int)
df_resort['days_open_last_year'] = df_resort['days_open_last_year'].astype(int)
df_resort['average_snowfall(cm)'] = df_resort['average_snowfall(cm)'].astype(int)
df_resort['beginner_runs(%)'] = df_resort['beginner_runs(%)'].astype(int)
df_resort['intermediate_runs(%)'] = df_resort['intermediate_runs(%)'].astype(int)
df_resort['advanced_runs(%)'] = df_resort['advanced_runs(%)'].astype(int)
df_resort['expert_runs(%)'] = df_resort['expert_runs(%)'].astype(int)

# %%
display(df_resort)
df_snow
# Out:
#          location           resort  pass  total_lifts  summit_height(ft)  \
# 0            Utah             Alta  Ikon            6              11068
# 1        Colorado   Arapahoe Basin  Ikon            9              13050
# 2        Colorado   Aspen Snowmass  Ikon           40              12510
# 3      California    Bear Mountain  Ikon           12               8805
# 4         Montana          Big Sky  Ikon           36              11166
# ..            ...              ...   ...          ...                ...
# 79       Colorado    Crested Butte  Epic           14              12162
# 81  New-Hampshire    Mount Sunapee  Epic           10               2743
# 82       Michigan     Mt. Brighton  Epic           13               1330
# 85       Colorado        Telluride  Epic           17              13150
# 86      Wisconsin  Wilmot Mountain  Epic           11               1030
#
#     vertical_drop(ft)  base_elevation(ft)  runs_in_total  longest_run(mi)  \
# 0                2538                8530            119              1.3
# 1                2530               10780            147              1.5
# 2                4406                8104            336              5.3
# 3                1665                7140             15              1.5
# 4                4350                7500            317              6.0
# ..                ...                 ...            ...              ...
# 79               3062                9375            121              2.6
# 81               1510                1233             66              0.8
# 82                230                1100             25              0.1
# 85               4425                8725            147              4.6
# 86                230                 800             21              0.5
#
#    skiable_terrain(ac)  projected_days_open  days_open_last_year  years_open  \
# 0                 2614                  142                  156          84
# 1                 1428                  270                  234          76
# 2                 5517                  148                  150          75
# 3                  198                  135                  122          79
# 4                 5800                  143                  144          49
# ..                 ...                  ...                  ...         ...
# 79                1547                  137                  145          61
# 81                 232                  130                  130          74
# 82                 130                   99                  111          62
# 85                2000                  129                  136          50
# 86                 135                  139                  125          84
#
#     average_snowfall(cm)  beginner_runs(%)  intermediate_runs(%)  \
# 0                    547                 0                     0
# 1                    350                 7                    20
# 2                    300                 0                     0
# 3                    100                20                    33
# 4                    400                15                    25
# ..                   ...               ...                   ...
# 79                   234                14                    25
# 81                   100                30                    46
# 82                    60                24                    44
# 85                   280                16                    30
# 86                    70                33                    33
#
#     advanced_runs(%)  expert_runs(%)  night_skiing
# 0                  0               0         False
# 1                 49              24         False
# 2                  0               0         False
# 3                 33              13         False
# 4                 42              18         False
# ..               ...             ...           ...
# 79                25              36         False
# 81                11              13         False
# 82                24               8          True
# 85                21              34         False
# 86                33               0          True
#
# [65 rows x 19 columns]
#       location           resort  pass            year  total_snowfall(cm)  \
# 0         Utah             Alta  Ikon     2012 - 2013                 366
# 1         Utah             Alta  Ikon     2013 - 2014                 353
# 2         Utah             Alta  Ikon     2014 - 2015                 278
# 3         Utah             Alta  Ikon     2015 - 2016                 286
# 4         Utah             Alta  Ikon     2016 - 2017                 304
# ..         ...              ...   ...             ...                 ...
# 865  Wisconsin  Wilmot Mountain  Epic     2017 - 2018                  37
# 866  Wisconsin  Wilmot Mountain  Epic     2018 - 2019                  35
# 867  Wisconsin  Wilmot Mountain  Epic     2019 - 2020                   6
# 868  Wisconsin  Wilmot Mountain  Epic     2020 - 2021                  22
# 869  Wisconsin  Wilmot Mountain  Epic  2021 - To Date                  10
#
#      snowfall_days  average_base_depth(cm)  average_summit_depth(cm)  \
# 0               76                      50                        52
# 1               68                      64                        60
# 2               56                      44                        42
# 3               60                      51                        51
# 4               55                      64                        63
# ..             ...                     ...                       ...
# 865             15                       6                        10
# 866              9                       9                        15
# 867              1                       9                        17
# 868             11                       9                        10
# 869              4                      19                        18
#
#      max_base_depth(cm)  biggest_snowfall(cm)
# 0                   113                    17
# 1                   124                    14
# 2                    90                    19
# 3                   116                    19
# 4                   145                    19
# ..                  ...                   ...
# 865                  28                     8
# 866                  24                    10
# 867                  29                     6
# 868                  20                     5
# 869                  64                     4
#
# [870 rows x 10 columns]

# %% [markdown]
# ## Merged data

# %%
df_final = pd.merge(df_snow, df_resort, on=['location', 'resort', 'pass'])

# %%
df_final.head(50)
# Out:
#       location          resort  pass            year  total_snowfall(cm)  \
# 0         Utah            Alta  Ikon     2012 - 2013                 366
# 1         Utah            Alta  Ikon     2013 - 2014                 353
# 2         Utah            Alta  Ikon     2014 - 2015                 278
# 3         Utah            Alta  Ikon     2015 - 2016                 286
# 4         Utah            Alta  Ikon     2016 - 2017                 304
# 5         Utah            Alta  Ikon     2017 - 2018                 190
# 6         Utah            Alta  Ikon     2018 - 2019                 656
# 7         Utah            Alta  Ikon     2019 - 2020                 326
# 8         Utah            Alta  Ikon     2020 - 2021                 330
# 9         Utah            Alta  Ikon  2021 - To Date                 265
# 10    Colorado  Arapahoe Basin  Ikon     2012 - 2013                 281
# 11    Colorado  Arapahoe Basin  Ikon     2013 - 2014                 418
# 12    Colorado  Arapahoe Basin  Ikon     2014 - 2015                 314
# 13    Colorado  Arapahoe Basin  Ikon     2015 - 2016                 290
# 14    Colorado  Arapahoe Basin  Ikon     2016 - 2017                 345
# 15    Colorado  Arapahoe Basin  Ikon     2017 - 2018                 247
# 16    Colorado  Arapahoe Basin  Ikon     2018 - 2019                 329
# 17    Colorado  Arapahoe Basin  Ikon     2019 - 2020                 173
# 18    Colorado  Arapahoe Basin  Ikon     2020 - 2021                 236
# 19    Colorado  Arapahoe Basin  Ikon  2021 - To Date                 100
# 20    Colorado  Aspen Snowmass  Ikon     2012 - 2013                 309
# 21    Colorado  Aspen Snowmass  Ikon     2013 - 2014                 326
# 22    Colorado  Aspen Snowmass  Ikon     2014 - 2015                 220
# 23    Colorado  Aspen Snowmass  Ikon     2015 - 2016                 305
# 24    Colorado  Aspen Snowmass  Ikon     2016 - 2017                 319
# 25    Colorado  Aspen Snowmass  Ikon     2017 - 2018                 233
# 26    Colorado  Aspen Snowmass  Ikon     2018 - 2019                 396
# 27    Colorado  Aspen Snowmass  Ikon     2019 - 2020                 233
# 28    Colorado  Aspen Snowmass  Ikon     2020 - 2021                 257
# 29    Colorado  Aspen Snowmass  Ikon  2021 - To Date                 294
# 30  California   Bear Mountain  Ikon     2012 - 2013                 102
# 31  California   Bear Mountain  Ikon     2013 - 2014                  38
# 32  California   Bear Mountain  Ikon     2014 - 2015                  51
# 33  California   Bear Mountain  Ikon     2015 - 2016                  81
# 34  California   Bear Mountain  Ikon     2016 - 2017                 174
# 35  California   Bear Mountain  Ikon     2017 - 2018                  36
# 36  California   Bear Mountain  Ikon     2018 - 2019                 133
# 37  California   Bear Mountain  Ikon     2019 - 2020                  79
# 38  California   Bear Mountain  Ikon     2020 - 2021                 110
# 39  California   Bear Mountain  Ikon  2021 - To Date                  83
# 40     Montana         Big Sky  Ikon     2012 - 2013                 395
# 41     Montana         Big Sky  Ikon     2013 - 2014                 466
# 42     Montana         Big Sky  Ikon     2014 - 2015                 236
# 43     Montana         Big Sky  Ikon     2015 - 2016                 294
# 44     Montana         Big Sky  Ikon     2016 - 2017                 277
# 45     Montana         Big Sky  Ikon     2017 - 2018                 325
# 46     Montana         Big Sky  Ikon     2018 - 2019                 266
# 47     Montana         Big Sky  Ikon     2019 - 2020                  72
# 48     Montana         Big Sky  Ikon     2020 - 2021                 162
# 49     Montana         Big Sky  Ikon  2021 - To Date                 143
#
#     snowfall_days  average_base_depth(cm)  average_summit_depth(cm)  \
# 0              76                      50                        52
# 1              68                      64                        60
# 2              56                      44                        42
# 3              60                      51                        51
# 4              55                      64                        63
# 5              42                      54                        51
# 6              92                      74                        73
# 7              53                      50                        49
# 8              52                      48                        50
# 9              46                      72                        71
# 10             93                      35                        35
# 11            115                      56                        55
# 12             98                      39                        39
# 13             88                      48                        48
# 14             89                      53                        52
# 15             70                      40                        39
# 16             99                      56                        56
# 17             57                      34                        33
# 18             87                      39                        38
# 19             40                      43                        42
# 20             70                      24                        34
# 21             61                      39                        52
# 22             53                      24                        36
# 23             62                      36                        51
# 24             69                      26                        45
# 25             42                      21                        36
# 26             82                      83                        57
# 27             60                      21                        30
# 28             59                      24                        35
# 29             48                      34                        55
# 30             16                      14                        22
# 31              8                       6                        13
# 32             10                       7                        14
# 33             16                      16                        24
# 34             19                      19                        26
# 35             10                      14                        20
# 36             19                      22                        32
# 37             13                      20                        23
# 38             15                      23                        31
# 39             12                      28                        37
# 40             92                      31                        44
# 41             81                      38                        51
# 42             60                      25                        35
# 43             79                      25                        44
# 44             78                      28                        41
# 45             80                      40                        58
# 46             77                      31                        51
# 47             28                      24                        40
# 48             55                      27                        42
# 49             47                      19                        41
#
#     max_base_depth(cm)  biggest_snowfall(cm)  ...  skiable_terrain(ac)  \
# 0                  113                    17  ...                 2614
# 1                  124                    14  ...                 2614
# 2                   90                    19  ...                 2614
# 3                  116                    19  ...                 2614
# 4                  145                    19  ...                 2614
# 5                  115                    15  ...                 2614
# 6                  180                    27  ...                 2614
# 7                  134                    24  ...                 2614
# 8                  116                    27  ...                 2614
# 9                  114                    24  ...                 2614
# 10                  69                    14  ...                 1428
# 11                  90                    15  ...                 1428
# 12                  62                    19  ...                 1428
# 13                  80                    15  ...                 1428
# 14                  78                    18  ...                 1428
# 15                  73                    14  ...                 1428
# 16                  99                    14  ...                 1428
# 17                  69                    15  ...                 1428
# 18                  62                     9  ...                 1428
# 19                  62                    13  ...                 1428
# 20                  61                    15  ...                 5517
# 21                  90                    24  ...                 5517
# 22                  57                    11  ...                 5517
# 23                  72                    14  ...                 5517
# 24                  61                    19  ...                 5517
# 25                  52                    16  ...                 5517
# 26                8181                    22  ...                 5517
# 27                  49                    15  ...                 5517
# 28                  59                    20  ...                 5517
# 29                  87                    19  ...                 5517
# 30                  36                    18  ...                  198
# 31                  12                    10  ...                  198
# 32                  18                    11  ...                  198
# 33                  40                    18  ...                  198
# 34                  46                    24  ...                  198
# 35                  36                     8  ...                  198
# 36                  44                    18  ...                  198
# 37                  40                    18  ...                  198
# 38                  46                    28  ...                  198
# 39                  58                    13  ...                  198
# 40                  59                    16  ...                 5800
# 41                  86                    26  ...                 5800
# 42                  49                    16  ...                 5800
# 43                  64                    12  ...                 5800
# 44                  58                    13  ...                 5800
# 45                  90                    15  ...                 5800
# 46                 265                    14  ...                 5800
# 47                  61                     9  ...                 5800
# 48                  59                    11  ...                 5800
# 49                  38                    10  ...                 5800
#
#     projected_days_open  days_open_last_year  years_open  \
# 0                   142                  156          84
# 1                   142                  156          84
# 2                   142                  156          84
# 3                   142                  156          84
# 4                   142                  156          84
# 5                   142                  156          84
# 6                   142                  156          84
# 7                   142                  156          84
# 8                   142                  156          84
# 9                   142                  156          84
# 10                  270                  234          76
# 11                  270                  234          76
# 12                  270                  234          76
# 13                  270                  234          76
# 14                  270                  234          76
# 15                  270                  234          76
# 16                  270                  234          76
# 17                  270                  234          76
# 18                  270                  234          76
# 19                  270                  234          76
# 20                  148                  150          75
# 21                  148                  150          75
# 22                  148                  150          75
# 23                  148                  150          75
# 24                  148                  150          75
# 25                  148                  150          75
# 26                  148                  150          75
# 27                  148                  150          75
# 28                  148                  150          75
# 29                  148                  150          75
# 30                  135                  122          79
# 31                  135                  122          79
# 32                  135                  122          79
# 33                  135                  122          79
# 34                  135                  122          79
# 35                  135                  122          79
# 36                  135                  122          79
# 37                  135                  122          79
# 38                  135                  122          79
# 39                  135                  122          79
# 40                  143                  144          49
# 41                  143                  144          49
# 42                  143                  144          49
# 43                  143                  144          49
# 44                  143                  144          49
# 45                  143                  144          49
# 46                  143                  144          49
# 47                  143                  144          49
# 48                  143                  144          49
# 49                  143                  144          49
#
#     average_snowfall(cm)  beginner_runs(%) intermediate_runs(%)  \
# 0                    547                 0                    0
# 1                    547                 0                    0
# 2                    547                 0                    0
# 3                    547                 0                    0
# 4                    547                 0                    0
# 5                    547                 0                    0
# 6                    547                 0                    0
# 7                    547                 0                    0
# 8                    547                 0                    0
# 9                    547                 0                    0
# 10                   350                 7                   20
# 11                   350                 7                   20
# 12                   350                 7                   20
# 13                   350                 7                   20
# 14                   350                 7                   20
# 15                   350                 7                   20
# 16                   350                 7                   20
# 17                   350                 7                   20
# 18                   350                 7                   20
# 19                   350                 7                   20
# 20                   300                 0                    0
# 21                   300                 0                    0
# 22                   300                 0                    0
# 23                   300                 0                    0
# 24                   300                 0                    0
# 25                   300                 0                    0
# 26                   300                 0                    0
# 27                   300                 0                    0
# 28                   300                 0                    0
# 29                   300                 0                    0
# 30                   100                20                   33
# 31                   100                20                   33
# 32                   100                20                   33
# 33                   100                20                   33
# 34                   100                20                   33
# 35                   100                20                   33
# 36                   100                20                   33
# 37                   100                20                   33
# 38                   100                20                   33
# 39                   100                20                   33
# 40                   400                15                   25
# 41                   400                15                   25
# 42                   400                15                   25
# 43                   400                15                   25
# 44                   400                15                   25
# 45                   400                15                   25
# 46                   400                15                   25
# 47                   400                15                   25
# 48                   400                15                   25
# 49                   400                15                   25
#
#     advanced_runs(%)  expert_runs(%)  night_skiing
# 0                  0               0         False
# 1                  0               0         False
# 2                  0               0         False
# 3                  0               0         False
# 4                  0               0         False
# 5                  0               0         False
# 6                  0               0         False
# 7                  0               0         False
# 8                  0               0         False
# 9                  0               0         False
# 10                49              24         False
# 11                49              24         False
# 12                49              24         False
# 13                49              24         False
# 14                49              24         False
# 15                49              24         False
# 16                49              24         False
# 17                49              24         False
# 18                49              24         False
# 19                49              24         False
# 20                 0               0         False
# 21                 0               0         False
# 22                 0               0         False
# 23                 0               0         False
# 24                 0               0         False
# 25                 0               0         False
# 26                 0               0         False
# 27                 0               0         False
# 28                 0               0         False
# 29                 0               0         False
# 30                33              13         False
# 31                33              13         False
# 32                33              13         False
# 33                33              13         False
# 34                33              13         False
# 35                33              13         False
# 36                33              13         False
# 37                33              13         False
# 38                33              13         False
# 39                33              13         False
# 40                42              18         False
# 41                42              18         False
# 42                42              18         False
# 43                42              18         False
# 44                42              18         False
# 45                42              18         False
# 46                42              18         False
# 47                42              18         False
# 48                42              18         False
# 49                42              18         False
#
# [50 rows x 26 columns]
